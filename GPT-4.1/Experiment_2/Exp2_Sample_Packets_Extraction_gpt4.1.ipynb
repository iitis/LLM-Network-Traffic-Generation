# %%
import os
import pandas as pd

data_directory = r'../../Datasets'
data_name = r'two_ways_communication'

file_name = os.path.join(data_directory, data_name + '.csv')

df = pd.read_csv(file_name)
df.head(5)
# Out:
#    No.       Time  Source Destination   Protocol  Length  \
# 0   46   3.486046  0x1de6   Broadcast     ZigBee      80
# 1  177  11.472175  0xd7a7      0x1de6  ZigBee HA      56
# 2  179  11.503840  0xd7a7      0x1de6  ZigBee HA      52
# 3  181  11.527324  0x1de6      0xd7a7  ZigBee HA      69
# 4  185  11.559638  0x1de6      0xd7a7  ZigBee HA      61
#
#                                       Info
# 0                              Link Status
# 1           ZCL: Read Attributes, Seq: 216
# 2           ZCL: Read Attributes, Seq: 217
# 3  ZCL: Read Attributes Response, Seq: 216
# 4  ZCL: Read Attributes Response, Seq: 217

# %% [markdown]
# * Detailed Information of Packages

# %%
unique_source = df['Source'].nunique()
print(f"Number of unique_source  : {unique_source }")

Source_names = df['Source'].unique()
print(Source_names)
# Out:
# Number of unique_source  : 2
# ['0x1de6' '0xd7a7']

# %%
unique_destination = df['Destination'].nunique()
print(f"Number of Unique destination : {unique_destination}")

destination_names = df['Destination'].unique()
print(destination_names)
# Broadcast == 0xfffc
# Out:
# Number of Unique destination : 3
# ['Broadcast' '0x1de6' '0xd7a7']

# %%
unique_protocols = df['Protocol'].nunique()
print(f"Number of Unique protocol : {unique_protocols}")

protocol_names = df['Protocol'].unique()
print(protocol_names)
# Out:
# Number of Unique protocol : 3
# ['ZigBee' 'ZigBee HA' 'ZigBee ZDP']

# %%
df['Length'] = pd.to_numeric(df['Length'], errors='coerce')  # makes errors NaN

min_length = df['Length'].min()
max_length = df['Length'].max()
print(f"Length range: min = {min_length}, max = {max_length}")
# Out:
# Length range: min = 48, max = 114

# %%
length_counts = df['Length'].value_counts().sort_index()

print("Length values ​​and frequencies:")
print(length_counts)
# Out:
# Length values ​​and frequencies:
# Length
# 48          1
# 49       3376
# 50       9461
# 51          3
# 52     119010
# 53       4347
# 54       6514
# 55         23
# 56     119038
# 57        353
# 58       3282
# 59          5
# 60        128
# 61      33404
# 62       2125
# 63      87260
# 65          7
# 66          1
# 68       1896
# 69     124238
# 71      51609
# 72       2095
# 74        209
# 77       7955
# 80      49733
# 82          2
# 84          2
# 100       139
# 105         1
# 109         1
# 111         1
# 114         1
# Name: count, dtype: int64

# %%
df['Info_clean'] = df['Info'].str.split('Seq:').str[0].str.strip()

unique_info_types = df['Info_clean'].unique()
num_unique_info_types = len(unique_info_types)

print(f"Number of different info types: {num_unique_info_types}")
# Out:
# Number of different info types: 33

# %%
info_type_freq = df['Info_clean'].value_counts().sort_index()

print("Info Types ​​and frequencies:")
print(info_type_freq)
# Out:
# Info Types ​​and frequencies:
# Info_clean
# Link Status                                                             111268
# Network Status, 0x1de6: Many-to-One Route Failure                           69
# Network Status, 0x6395: Many-to-One Route Failure                            1
# Network Status, 0x9f06: Many-to-One Route Failure                            1
# Network Status, 0xb85c: Many-to-One Route Failure                           14
# Network Status, 0xdfe1: Many-to-One Route Failure                            1
# Node Descriptor Request, Nwk Addr: 0x1de6                                    1
# Node Descriptor Response, Rev: 22, Nwk Addr: 0x1de6, Status: Success         1
# Route Reply, Responder: 0x1de6, Originator: 0xd7a7                          36
# Route Reply, Responder: 0x2a30, Originator: 0xd7a7                          19
# Route Reply, Responder: 0x9f06, Originator: 0xd7a7                           3
# Route Reply, Responder: 0xa163, Originator: 0xd7a7                           1
# Route Reply, Responder: 0xb85c, Originator: 0xd7a7                          44
# Route Reply, Responder: 0xd7a7, Originator: 0x1de6                           1
# Route Reply, Responder: 0xdfe1, Originator: 0xd7a7                          34
# Route Reply, Responder: 0xe8eb, Originator: 0xd7a7                           3
# Route Request, Dst: 0xd7a7, Src: 0x1de6                                      4
# Simple Descriptor Request, Nwk Addr: 0x1de6, Endpoint: 11                    1
# Simple Descriptor Response, Nwk Addr: 0x1de6, Status: Success                2
# Unknown Command: 0x00,                                                      23
# Unknown Command: 0xc0,                                                       2
# Unknown Command: 0xc1,                                                       2
# ZCL Groups: Get Group Membership Response,                                3149
# ZCL Groups: Get Group Membership,                                         3120
# ZCL OTA: Query Next Image Request,                                         266
# ZCL OTA: Query Next Image Response,                                        255
# ZCL Scenes: Get Scene Membership Response,                                3106
# ZCL Scenes: Get Scene Membership,                                         3057
# ZCL: Default Response,                                                       2
# ZCL: Read Attributes Response,                                          252852
# ZCL: Read Attributes,                                                   248876
# ZCL: Write Attributes Response,                                              3
# ZCL: Write Attributes,                                                       3
# Name: count, dtype: int64

# %%
with open('Experiment_2_info_type_freq.txt', 'w') as f:
    f.write("Length values and frequencies:\n")
    f.write(info_type_freq.to_string())

# %%
df.head(3)
# Out:
#    No.       Time  Source Destination   Protocol  Length  \
# 0   46   3.486046  0x1de6   Broadcast     ZigBee      80
# 1  177  11.472175  0xd7a7      0x1de6  ZigBee HA      56
# 2  179  11.503840  0xd7a7      0x1de6  ZigBee HA      52
#
#                              Info             Info_clean
# 0                     Link Status            Link Status
# 1  ZCL: Read Attributes, Seq: 216  ZCL: Read Attributes,
# 2  ZCL: Read Attributes, Seq: 217  ZCL: Read Attributes,

# %% [markdown]
# *CHOOSE FIRST M MINUTES PACKAGES*

# %%
seconds = 60 # 60 seconds = 1 minute
num_minute = 10
total_second = seconds * num_minute

df_min = df[df['Time'] <= total_second]
df_min.head(10)
# Out:
#    No.       Time  Source Destination   Protocol  Length  \
# 0   46   3.486046  0x1de6   Broadcast     ZigBee      80
# 1  177  11.472175  0xd7a7      0x1de6  ZigBee HA      56
# 2  179  11.503840  0xd7a7      0x1de6  ZigBee HA      52
# 3  181  11.527324  0x1de6      0xd7a7  ZigBee HA      69
# 4  185  11.559638  0x1de6      0xd7a7  ZigBee HA      61
# 5  243  17.728144  0x1de6   Broadcast     ZigBee      80
# 6  360  24.215512  0xd7a7      0x1de6  ZigBee HA      56
# 7  362  24.243231  0xd7a7      0x1de6  ZigBee HA      52
# 8  364  24.272475  0x1de6      0xd7a7  ZigBee HA      69
# 9  368  24.298233  0x1de6      0xd7a7  ZigBee HA      61
#
#                                       Info                      Info_clean
# 0                              Link Status                     Link Status
# 1           ZCL: Read Attributes, Seq: 216           ZCL: Read Attributes,
# 2           ZCL: Read Attributes, Seq: 217           ZCL: Read Attributes,
# 3  ZCL: Read Attributes Response, Seq: 216  ZCL: Read Attributes Response,
# 4  ZCL: Read Attributes Response, Seq: 217  ZCL: Read Attributes Response,
# 5                              Link Status                     Link Status
# 6           ZCL: Read Attributes, Seq: 239           ZCL: Read Attributes,
# 7           ZCL: Read Attributes, Seq: 240           ZCL: Read Attributes,
# 8  ZCL: Read Attributes Response, Seq: 239  ZCL: Read Attributes Response,
# 9  ZCL: Read Attributes Response, Seq: 240  ZCL: Read Attributes Response,

# %%
print("There are", len(df_min), "packages in first", num_minute , "minutes")
# Out:
# There are 220 packages in first 10 minutes

# %%
info_type_freq_min = df_min['Info_clean'].value_counts().sort_index()
print(info_type_freq_min)
# Out:
# Info_clean
# Link Status                                   37
# ZCL Groups: Get Group Membership Response,     1
# ZCL Groups: Get Group Membership,              1
# ZCL Scenes: Get Scene Membership Response,     1
# ZCL Scenes: Get Scene Membership,              1
# ZCL: Read Attributes Response,                87
# ZCL: Read Attributes,                         92
# Name: count, dtype: int64

# %%
df_min
# Out:
#       No.        Time  Source Destination   Protocol  Length  \
# 0      46    3.486046  0x1de6   Broadcast     ZigBee      80
# 1     177   11.472175  0xd7a7      0x1de6  ZigBee HA      56
# 2     179   11.503840  0xd7a7      0x1de6  ZigBee HA      52
# 3     181   11.527324  0x1de6      0xd7a7  ZigBee HA      69
# 4     185   11.559638  0x1de6      0xd7a7  ZigBee HA      61
# ..    ...         ...     ...         ...        ...     ...
# 215  8707  588.984730  0xd7a7      0x1de6  ZigBee HA      56
# 216  8709  589.013933  0xd7a7      0x1de6  ZigBee HA      52
# 217  8711  589.043310  0x1de6      0xd7a7  ZigBee HA      69
# 218  8715  589.070307  0x1de6      0xd7a7  ZigBee HA      61
# 219  8740  591.446555  0x1de6   Broadcast     ZigBee      80
#
#                                         Info                      Info_clean
# 0                                Link Status                     Link Status
# 1             ZCL: Read Attributes, Seq: 216           ZCL: Read Attributes,
# 2             ZCL: Read Attributes, Seq: 217           ZCL: Read Attributes,
# 3    ZCL: Read Attributes Response, Seq: 216  ZCL: Read Attributes Response,
# 4    ZCL: Read Attributes Response, Seq: 217  ZCL: Read Attributes Response,
# ..                                       ...                             ...
# 215           ZCL: Read Attributes, Seq: 203           ZCL: Read Attributes,
# 216           ZCL: Read Attributes, Seq: 204           ZCL: Read Attributes,
# 217  ZCL: Read Attributes Response, Seq: 203  ZCL: Read Attributes Response,
# 218  ZCL: Read Attributes Response, Seq: 204  ZCL: Read Attributes Response,
# 219                              Link Status                     Link Status
#
# [220 rows x 8 columns]

# %%
# Convert and save to JSON file
data_directory = r"..\Datasets"

json_file_path = '\Experiment_2_input_sample.json'
df_min.to_json(data_directory + json_file_path, orient='records', lines=True)

# A message indicating that the file was saved successfully
print(f"JSON file saved as '{json_file_path}'.")
# Out:
# JSON file saved as '\Experiment_2_input_sample.json'.
# <>:4: SyntaxWarning: invalid escape sequence '\E'
# <>:4: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\nkelesoglu\AppData\Local\Temp\ipykernel_14928\2031524636.py:4: SyntaxWarning: invalid escape sequence '\E'
#   json_file_path = '\Experiment_2_input_sample.json'
