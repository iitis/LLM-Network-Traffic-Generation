# %%
import json
import os

data = []

with open('../Datasets/Experiment_1_one_way_communication_10_minute_input_sample.json', 'r') as file:
    for line in file:
        data.append(json.loads(line))

print(data)
# Out:
# [{'No.': 1, 'Time': 0.0, 'Source': '0x1de6', 'Destination': 'Broadcast', 'Protocol': 'ZigBee', 'Length': 80, 'Info': 'Link Status', 'Info_clean': 'Link Status'}, {'No.': 2, 'Time': 8.041278, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 69, 'Info': 'ZCL: Read Attributes Response, Seq: 216', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 3, 'Time': 8.073592, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 61, 'Info': 'ZCL: Read Attributes Response, Seq: 217', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 4, 'Time': 14.242098, 'Source': '0x1de6', 'Destination': 'Broadcast', 'Protocol': 'ZigBee', 'Length': 80, 'Info': 'Link Status', 'Info_clean': 'Link Status'}, {'No.': 5, 'Time': 20.786429, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 69, 'Info': 'ZCL: Read Attributes Response, Seq: 239', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 6, 'Time': 20.812187, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 61, 'Info': 'ZCL: Read Attributes Response, Seq: 240', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 7, 'Time': 28.563272, 'Source': '0x1de6', 'Destination': 'Broadcast', 'Protocol': 'ZigBee', 'Length': 80, 'Info': 'Link Status', 'Info_clean': 'Link Status'}, {'No.': 8, 'Time': 33.56803, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 69, 'Info': 'ZCL: Read Attributes Response, Seq: 6', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 9, 'Time': 33.597885, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 61, 'Info': 'ZCL: Read Attributes Response, Seq: 7', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 10, 'Time': 43.930759, 'Source': '0x1de6', 'Destination': 'Broadcast', 'Protocol': 'ZigBee', 'Length': 80, 'Info': 'Link Status', 'Info_clean': 'Link Status'}, {'No.': 11, 'Time': 46.250961, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 69, 'Info': 'ZCL: Read Attributes Response, Seq: 30', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 12, 'Time': 46.2785, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 61, 'Info': 'ZCL: Read Attributes Response, Seq: 31', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 13, 'Time': 47.393595, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 58, 'Info': 'ZCL Groups: Get Group Membership Response, Seq: 32', 'Info_clean': 'ZCL Groups: Get Group Membership Response,'}, {'No.': 14, 'Time': 48.503144, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 69, 'Info': 'ZCL Scenes: Get Scene Membership Response, Seq: 33', 'Info_clean': 'ZCL Scenes: Get Scene Membership Response,'}, {'No.': 15, 'Time': 49.632451, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 72, 'Info': 'ZCL: Read Attributes Response, Seq: 34', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 16, 'Time': 50.717945, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 53, 'Info': 'ZCL: Read Attributes Response, Seq: 35', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 17, 'Time': 50.749067, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 53, 'Info': 'ZCL: Read Attributes Response, Seq: 36', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 18, 'Time': 50.783941, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 54, 'Info': 'ZCL: Read Attributes Response, Seq: 37', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 19, 'Time': 50.814829, 'Source': '0x1de6', 'Destination': '0xd7a7', 'Protocol': 'ZigBee HA', 'Length': 62, 'Info': 'ZCL: Read Attributes Response, Seq: 38', 'Info_clean': 'ZCL: Read Attributes Response,'}, {'No.': 20, 'Time': 59.498527, 'Source': '0x1de6', 'Destination': 'Broadcast', 'Protoco ...

# %%
Source_Type = set(item['Source'] for item in data)
num_unique_src = len(Source_Type)

Sender = []
for src in Source_Type:
    Sender.append(src)
    print(src)

print("Senders: ", Sender)
# Out:
# 0x1de6
# Senders:  ['0x1de6']

# %%
Destination_Type = set(item['Destination'] for item in data)
num_unique_dst = len(Destination_Type)

Receiver = []
for dst in Destination_Type:
    Receiver.append(dst)
    print(dst)

print("Receivers: ", Receiver)
# Out:
# 0xd7a7
# Broadcast
# Receivers:  ['0xd7a7', 'Broadcast']

# %%
""" Change Broadcast with the address """
for item in data:
    if item['Destination'] == 'Broadcast':
        item['Destination'] = '0xfffc'

# %%
Destination_Type = set(item['Destination'] for item in data)
num_unique_dst = len(Destination_Type)

Receiver = []
for dst in Destination_Type:
    Receiver.append(dst)
    print(dst)

print("Receivers: ", Receiver)
# Out:
# 0xfffc
# 0xd7a7
# Receivers:  ['0xfffc', '0xd7a7']

# %%
Protocol_Type = set(item['Protocol'] for item in data)
num_unique_protocol = len(Protocol_Type)

Protocols = []
for protocols in Protocol_Type:
    Protocols.append(protocols)
    print(protocols)

print("Protocols: ", Protocols)
# Out:
# ZigBee HA
# ZigBee
# Protocols:  ['ZigBee HA', 'ZigBee']

# %%
""" Create sample prompt from json file """
Sample_Packets= []

for item in data:
    sample_packets = {
        'time': str(item['Time']),
        'src': item['Source'],
        'dst': item['Destination'],
        'protocol': item['Protocol'],
        'length': str(item['Length']),
        'info': item['Info']
    }
    Sample_Packets.append(sample_packets)
    #print(sample_prompt)
print(Sample_Packets)
# Out:
# [{'time': '0.0', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '8.041278', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 216'}, {'time': '8.073592', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 217'}, {'time': '14.242098', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '20.786429', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 239'}, {'time': '20.812187', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 240'}, {'time': '28.563272', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '33.56803', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 6'}, {'time': '33.597885', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 7'}, {'time': '43.930759', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '46.250961', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 30'}, {'time': '46.2785', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 31'}, {'time': '47.393595', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '58', 'info': 'ZCL Groups: Get Group Membership Response, Seq: 32'}, {'time': '48.503144', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL Scenes: Get Scene Membership Response, Seq: 33'}, {'time': '49.632451', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '72', 'info': 'ZCL: Read Attributes Response, Seq: 34'}, {'time': '50.717945', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '53', 'info': 'ZCL: Read Attributes Response, Seq: 35'}, {'time': '50.749067', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '53', 'info': 'ZCL: Read Attributes Response, Seq: 36'}, {'time': '50.783941', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '54', 'info': 'ZCL: Read Attributes Response, Seq: 37'}, {'time': '50.814829', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '62', 'info': 'ZCL: Read Attributes Response, Seq: 38'}, {'time': '59.498527', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '73.910357', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '89.474602', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '105.724525', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '116.936803', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 119'}, {'time': '116.964937', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 120'}, {'time': '120.705166', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info': 'Link Status'}, {'time': '129.566399', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '69', 'info': 'ZCL: Read Attributes Response, Seq: 142'}, {'time': '129.598646', 'src': '0x1de6', 'dst': '0xd7a7', 'protocol': 'ZigBee HA', 'length': '61', 'info': 'ZCL: Read Attributes Response, Seq: 143'}, {'time': '138.578488', 'src': '0x1de6', 'dst': '0xfffc', 'protocol': 'ZigBee', 'length': '80', 'info ...

# %%
Sample_Packets
# Out:
# [{'time': '0.0',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '8.041278',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 216'},
#  {'time': '8.073592',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 217'},
#  {'time': '14.242098',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '20.786429',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 239'},
#  {'time': '20.812187',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 240'},
#  {'time': '28.563272',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '33.56803',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 6'},
#  {'time': '33.597885',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 7'},
#  {'time': '43.930759',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '46.250961',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 30'},
#  {'time': '46.2785',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 31'},
#  {'time': '47.393595',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '58',
#   'info': 'ZCL Groups: Get Group Membership Response, Seq: 32'},
#  {'time': '48.503144',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL Scenes: Get Scene Membership Response, Seq: 33'},
#  {'time': '49.632451',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '72',
#   'info': 'ZCL: Read Attributes Response, Seq: 34'},
#  {'time': '50.717945',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '53',
#   'info': 'ZCL: Read Attributes Response, Seq: 35'},
#  {'time': '50.749067',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '53',
#   'info': 'ZCL: Read Attributes Response, Seq: 36'},
#  {'time': '50.783941',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '54',
#   'info': 'ZCL: Read Attributes Response, Seq: 37'},
#  {'time': '50.814829',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '62',
#   'info': 'ZCL: Read Attributes Response, Seq: 38'},
#  {'time': '59.498527',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '73.910357',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '89.474602',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '105.724525',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '116.936803',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 119'},
#  {'time': '116.964937',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 120'},
#  {'time': '120.705166',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '129.566399',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 142'},
#  {'time': '129.598646',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 143'},
#  {'time': '138.578488',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '142.183473',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 165'},
#  {'time': '142.214611',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 166'},
#  {'time': '154.822637',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 188'},
#  {'time': '154.853387',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 189'},
#  {'time': '167.517743',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 211'},
#  {'time': '167.547097',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 212'},
#  {'time': '170.902734',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '180.179824',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 234'},
#  {'time': '180.206823',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 235'},
#  {'time': '186.181468',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '192.819268',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 1'},
#  {'time': '192.847521',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 2'},
#  {'time': '200.807612',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '205.513543',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 24'},
#  {'time': '205.542227',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 25'},
#  {'time': '216.215075',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '218.282798',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 47'},
#  {'time': '218.318797',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 48'},
#  {'time': '231.003844',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 70'},
#  {'time': '231.033367',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 71'},
#  {'time': '231.197901',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '243.676712',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 93'},
#  {'time': '243.706196',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 94'},
#  {'time': '248.140554',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '256.29995',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 116'},
#  {'time': '256.327789',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 117'},
#  {'time': '264.574357',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '268.935507',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 139'},
#  {'time': '268.965087',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 140'},
#  {'time': '281.137123',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '281.674261',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 162'},
#  {'time': '281.701797',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 163'},
#  {'time': '294.261751',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 185'},
#  {'time': '294.291503',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 186'},
#  {'time': '295.35536',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '306.93329',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 208'},
#  {'time': '306.966289',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 209'},
#  {'time': '313.037198',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '319.6431',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 231'},
#  {'time': '319.648348',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 232'},
#  {'time': '328.119622',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '332.245603',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 254'},
#  {'time': '332.272588',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 255'},
#  {'time': '343.8866',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '344.938398',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 23'},
#  {'time': '357.544864',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 45'},
#  {'time': '357.571859',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 46'},
#  {'time': '361.822787',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '370.25891',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 68'},
#  {'time': '370.279552',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 69'},
#  {'time': '376.578691',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '382.938656',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 91'},
#  {'time': '382.966772',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 92'},
#  {'time': '391.241324',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '395.628825',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 114'},
#  {'time': '395.658339',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 115'},
#  {'time': '407.661829',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '408.257646',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 137'},
#  {'time': '408.281148',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 138'},
#  {'time': '420.855455',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 160'},
#  {'time': '420.883455',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 161'},
#  {'time': '423.647611',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '433.585623',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 183'},
#  {'time': '433.614873',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 184'},
#  {'time': '441.071792',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '446.273718',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 206'},
#  {'time': '446.30684',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 207'},
#  {'time': '457.008261',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '458.953416',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 229'},
#  {'time': '458.981966',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 230'},
#  {'time': '471.637544',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 252'},
#  {'time': '471.663266',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 253'},
#  {'time': '473.444006',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '484.301431',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 19'},
#  {'time': '484.331934',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 20'},
#  {'time': '490.033448',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '496.934287',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 42'},
#  {'time': '496.963895',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 43'},
#  {'time': '504.231866',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '509.631826',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 66'},
#  {'time': '522.141571',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '522.364836',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 88'},
#  {'time': '522.39215',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 89'},
#  {'time': '534.982874',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 111'},
#  {'time': '535.012481',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 112'},
#  {'time': '538.637204',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '547.630711',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 134'},
#  {'time': '547.659685',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 135'},
#  {'time': '556.327142',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '560.268957',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 157'},
#  {'time': '560.295831',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 158'},
#  {'time': '572.204479',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '572.940696',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 180'},
#  {'time': '572.970194',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 181'},
#  {'time': '585.557264',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 203'},
#  {'time': '585.584261',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 204'},
#  {'time': '587.960509',
#   'src': '0x1de6',
#   'dst': '0xfffc',
#   'protocol': 'ZigBee',
#   'length': '80',
#   'info': 'Link Status'},
#  {'time': '598.239095',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '69',
#   'info': 'ZCL: Read Attributes Response, Seq: 226'},
#  {'time': '598.266714',
#   'src': '0x1de6',
#   'dst': '0xd7a7',
#   'protocol': 'ZigBee HA',
#   'length': '61',
#   'info': 'ZCL: Read Attributes Response, Seq: 227'}]

# %%
len(Sample_Packets)
# Out:
# 128

# %%
Sources = ["0x1de6"]
Destinations = ["0xd7a7", "0xfffc"]
Protocols = ["ZigBee", "ZigBee HA"]

# %%
import openai
import os

client = openai.OpenAI(api_key=os.environ["OPENAI_KEY"])

prompt = f"""
Examine the following sample ZigBee network traffic data and generate new traffic entries in a similar format.

Sample data: {Sample_Packets}

Rules:
- The format must match the sample exactly, including fields: 'time', 'src', 'dst', 'protocol', 'length', and 'info'.
- The field 'time' is given in seconds format.
- Use src addresses from this list: {Sources}
- Use dst addresses from this list: {Destinations}
- Use one of the following protocols: {Protocols}

Return output as JSON in the same format, generating new packets of 600 seconds starting from time = 0.
"""

response = client.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": "You are a realistic ZigBee network traffic generator. You will generate realistic syntetic ZigBee network traffic packets."},
        {"role": "user", "content": prompt}
    ],
    max_tokens= 32768
)

print(response.choices[0].message.content)

print("Input tokens used:", response.usage.prompt_tokens)
print("Output tokens generated:", response.usage.completion_tokens)
print("Total tokens used:", response.usage.total_tokens)
# Out:
# ```json
# [
#   {"time": "0.0", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "6.152837", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 10"},
#   {"time": "6.181201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 11"},
#   {"time": "13.672420", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "18.386910", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 32"},
#   {"time": "18.416540", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 33"},
#   {"time": "27.204111", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "32.009583", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 54"},
#   {"time": "32.038871", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 55"},
#   {"time": "40.721788", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "48.630188", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 77"},
#   {"time": "48.659374", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 78"},
#   {"time": "53.415222", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "58", "info": "ZCL Groups: Get Group Membership Response, Seq: 79"},
#   {"time": "54.933102", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL Scenes: Get Scene Membership Response, Seq: 80"},
#   {"time": "56.201168", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "72", "info": "ZCL: Read Attributes Response, Seq: 81"},
#   {"time": "58.081039", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "53", "info": "ZCL: Read Attributes Response, Seq: 82"},
#   {"time": "58.110344", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "53", "info": "ZCL: Read Attributes Response, Seq: 83"},
#   {"time": "58.141620", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "54", "info": "ZCL: Read Attributes Response, Seq: 84"},
#   {"time": "58.172542", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "62", "info": "ZCL: Read Attributes Response, Seq: 85"},
#   {"time": "68.092554", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "82.404321", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "95.916743", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "111.011094", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "119.104735", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 106"},
#   {"time": "119.134181", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 107"},
#   {"time": "125.281772", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "132.370804", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 129"},
#   {"time": "132.400087", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 130"},
#   {"time": "141.423850", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "145.749295", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 152"},
#   {"time": "145.777981", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 153"},
#   {"time": "157.965418", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 175"},
#   {"time": "157.995709", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 176"},
#   {"time": "168.703219", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "172.092401", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 199"},
#   {"time": "172.116079", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 200"},
#   {"time": "184.573691", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "191.828497", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 222"},
#   {"time": "191.851962", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 223"},
#   {"time": "198.356092", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "205.130681", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 246"},
#   {"time": "205.155287", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 247"},
#   {"time": "212.412331", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "218.433145", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 14"},
#   {"time": "218.458197", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 15"},
#   {"time": "229.655176", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 38"},
#   {"time": "229.681600", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 39"},
#   {"time": "230.979161", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "242.678090", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 62"},
#   {"time": "242.705454", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 63"},
#   {"time": "247.119580", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "255.346243", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 85"},
#   {"time": "255.372187", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 86"},
#   {"time": "263.701237", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "269.536021", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 109"},
#   {"time": "269.552607", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 110"},
#   {"time": "281.142117", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "281.771201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 133"},
#   {"time": "281.797201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 134"},
#   {"time": "294.205871", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 158"},
#   {"time": "294.231889", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 159"},
#   {"time": "301.362177", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "307.770909", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 182"},
#   {"time": "307.800230", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 183"},
#   {"time": "315.149009", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "320.469311", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 206"},
#   {"time": "320.496231", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 207"},
#   {"time": "328.111132", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "331.344196", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 230"},
#   {"time": "331.371768", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 231"},
#   {"time": "341.983490", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "347.155311", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 254"},
#   {"time": "347.184769", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 255"},
#   {"time": "352.472051", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "358.963104", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 20"},
#   {"time": "358.991184", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 21"},
#   {"time": "364.811204", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "371.681519", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 44"},
#   {"time": "371.709426", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 45"},
#   {"time": "378.287004", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "381.605703", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 68"},
#   {"time": "381.632146", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 69"},
#   {"time": "390.402912", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "394.912019", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 92"},
#   {"time": "394.939402", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 93"},
#   {"time": "403.433094", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "408.696231", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 116"},
#   {"time": "408.724296", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 117"},
#   {"time": "415.494002", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "421.396001", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 140"},
#   {"time": "421.424631", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 141"},
#   {"time": "429.556237", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "434.035109", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 164"},
#   {"time": "434.062600", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 165"},
#   {"time": "442.085178", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "448.571622", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 188"},
#   {"time": "448.599999", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 189"},
#   {"time": "454.583322", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "461.783103", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 212"},
#   {"time": "461.810293", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 213"},
#   {"time": "467.007166", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "473.274187", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 236"},
#   {"time": "473.299601", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 237"},
#   {"time": "478.586153", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "485.643274", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 4"},
#   {"time": "485.672980", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 5"},
#   {"time": "491.998021", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "496.067024", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 28"},
#   {"time": "496.095012", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 29"},
#   {"time": "504.839213", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "510.920137", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 52"},
#   {"time": "510.949301", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 53"},
#   {"time": "522.352001", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "525.109734", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 76"},
#   {"time": "525.136837", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 77"},
#   {"time": "534.992058", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 100"},
#   {"time": "535.020267", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 101"},
#   {"time": "539.874234", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "548.018205", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 124"},
#   {"time": "548.046583", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 125"},
#   {"time": "557.054411", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "560.994280", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 148"},
#   {"time": "561.021446", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 149"},
#   {"time": "572.375110", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "573.173104", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 172"},
#   {"time": "573.200428", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 173"},
#   {"time": "583.218215", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 196"},
#   {"time": "583.245539", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 197"},
#   {"time": "589.948055", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"}
# ]
# ```
# Input tokens used: 7419
# Output tokens generated: 7399
# Total tokens used: 14818

# %%
generated_message = response.choices[0].message.content

# %%
generated_message = generated_message[8:-4]

# %%
num_samples = len(generated_message.split('\n'))
print("Number of generated packages:", num_samples)
# Out:
# Number of generated packages: 131

# %% [markdown]
# * SAVE GENERATED TRAFFIC

# %%
data_directory = r"..\Generated_ZigBee_Packets"

with open(data_directory +"\Experiment_1_one_way_communication_10_minute_generated_message.json", "w") as f:
    json.dump(generated_message, f, indent=2)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\nkelesoglu\AppData\Local\Temp\ipykernel_7496\1037986109.py:3: SyntaxWarning: invalid escape sequence '\E'
#   with open(data_directory +"\Experiment_1_one_way_communication_10_minute_generated_message.json", "w") as f:

# %%
data_directory = r"..\Generated_ZigBee_Packets"
content = response.choices[0].message.content


with open(data_directory + "\Experiment_1_one_way_communication_10_minute_generated_message.csv", "w", encoding="utf-8") as f:
    f.write(content)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\E'
# <>:5: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\nkelesoglu\AppData\Local\Temp\ipykernel_7496\2257921805.py:5: SyntaxWarning: invalid escape sequence '\E'
#   with open(data_directory + "\Experiment_1_one_way_communication_10_minute_generated_message.csv", "w", encoding="utf-8") as f:

# %%
for line in generated_message.split('\n'):
    print(line)
# Out:
# ```json
# [
#   {"time": "0.0", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "6.152837", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 10"},
#   {"time": "6.181201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 11"},
#   {"time": "13.672420", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "18.386910", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 32"},
#   {"time": "18.416540", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 33"},
#   {"time": "27.204111", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "32.009583", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 54"},
#   {"time": "32.038871", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 55"},
#   {"time": "40.721788", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "48.630188", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 77"},
#   {"time": "48.659374", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 78"},
#   {"time": "53.415222", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "58", "info": "ZCL Groups: Get Group Membership Response, Seq: 79"},
#   {"time": "54.933102", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL Scenes: Get Scene Membership Response, Seq: 80"},
#   {"time": "56.201168", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "72", "info": "ZCL: Read Attributes Response, Seq: 81"},
#   {"time": "58.081039", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "53", "info": "ZCL: Read Attributes Response, Seq: 82"},
#   {"time": "58.110344", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "53", "info": "ZCL: Read Attributes Response, Seq: 83"},
#   {"time": "58.141620", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "54", "info": "ZCL: Read Attributes Response, Seq: 84"},
#   {"time": "58.172542", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "62", "info": "ZCL: Read Attributes Response, Seq: 85"},
#   {"time": "68.092554", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "82.404321", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "95.916743", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "111.011094", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "119.104735", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 106"},
#   {"time": "119.134181", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 107"},
#   {"time": "125.281772", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "132.370804", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 129"},
#   {"time": "132.400087", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 130"},
#   {"time": "141.423850", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "145.749295", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 152"},
#   {"time": "145.777981", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 153"},
#   {"time": "157.965418", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 175"},
#   {"time": "157.995709", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 176"},
#   {"time": "168.703219", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "172.092401", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 199"},
#   {"time": "172.116079", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 200"},
#   {"time": "184.573691", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "191.828497", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 222"},
#   {"time": "191.851962", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 223"},
#   {"time": "198.356092", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "205.130681", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 246"},
#   {"time": "205.155287", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 247"},
#   {"time": "212.412331", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "218.433145", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 14"},
#   {"time": "218.458197", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 15"},
#   {"time": "229.655176", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 38"},
#   {"time": "229.681600", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 39"},
#   {"time": "230.979161", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "242.678090", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 62"},
#   {"time": "242.705454", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 63"},
#   {"time": "247.119580", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "255.346243", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 85"},
#   {"time": "255.372187", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 86"},
#   {"time": "263.701237", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "269.536021", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 109"},
#   {"time": "269.552607", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 110"},
#   {"time": "281.142117", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "281.771201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 133"},
#   {"time": "281.797201", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 134"},
#   {"time": "294.205871", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 158"},
#   {"time": "294.231889", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 159"},
#   {"time": "301.362177", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "307.770909", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 182"},
#   {"time": "307.800230", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 183"},
#   {"time": "315.149009", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "320.469311", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 206"},
#   {"time": "320.496231", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 207"},
#   {"time": "328.111132", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "331.344196", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 230"},
#   {"time": "331.371768", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 231"},
#   {"time": "341.983490", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "347.155311", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 254"},
#   {"time": "347.184769", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 255"},
#   {"time": "352.472051", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "358.963104", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 20"},
#   {"time": "358.991184", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 21"},
#   {"time": "364.811204", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "371.681519", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 44"},
#   {"time": "371.709426", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 45"},
#   {"time": "378.287004", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "381.605703", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 68"},
#   {"time": "381.632146", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 69"},
#   {"time": "390.402912", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "394.912019", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 92"},
#   {"time": "394.939402", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 93"},
#   {"time": "403.433094", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "408.696231", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 116"},
#   {"time": "408.724296", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 117"},
#   {"time": "415.494002", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "421.396001", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 140"},
#   {"time": "421.424631", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 141"},
#   {"time": "429.556237", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "434.035109", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 164"},
#   {"time": "434.062600", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 165"},
#   {"time": "442.085178", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "448.571622", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 188"},
#   {"time": "448.599999", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 189"},
#   {"time": "454.583322", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "461.783103", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 212"},
#   {"time": "461.810293", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 213"},
#   {"time": "467.007166", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "473.274187", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 236"},
#   {"time": "473.299601", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 237"},
#   {"time": "478.586153", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "485.643274", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 4"},
#   {"time": "485.672980", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 5"},
#   {"time": "491.998021", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "496.067024", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 28"},
#   {"time": "496.095012", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 29"},
#   {"time": "504.839213", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "510.920137", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 52"},
#   {"time": "510.949301", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 53"},
#   {"time": "522.352001", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "525.109734", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 76"},
#   {"time": "525.136837", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 77"},
#   {"time": "534.992058", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 100"},
#   {"time": "535.020267", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 101"},
#   {"time": "539.874234", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "548.018205", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 124"},
#   {"time": "548.046583", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 125"},
#   {"time": "557.054411", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "560.994280", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 148"},
#   {"time": "561.021446", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 149"},
#   {"time": "572.375110", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"},
#   {"time": "573.173104", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 172"},
#   {"time": "573.200428", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 173"},
#   {"time": "583.218215", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "69", "info": "ZCL: Read Attributes Response, Seq: 196"},
#   {"time": "583.245539", "src": "0x1de6", "dst": "0xd7a7", "protocol": "ZigBee HA", "length": "61", "info": "ZCL: Read Attributes Response, Seq: 197"},
#   {"time": "589.948055", "src": "0x1de6", "dst": "0xfffc", "protocol": "ZigBee", "length": "80", "info": "Link Status"}
# ]
# ```
